# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', None)
pd.set_option('display.max_rows', None)

# %%
deliveries = pd.read_csv('deliveries.csv')
matches = pd.read_csv('matches.csv')

# %%
deliveries.head(2)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  ball    batsman non_striker    bowler  is_super_over  wide_runs  bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs player_dismissed dismissal_kind fielder
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     1  DA Warner    S Dhawan  TS Mills              0          0         0            0            0             0             0           0           0              NaN            NaN     NaN
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     2  DA Warner    S Dhawan  TS Mills              0          0         0            0            0             0             0           0           0              NaN            NaN     NaN

# %%
matches.head(2)
# Out:
#    id  season       city        date                team1                        team2                  toss_winner toss_decision  result  dl_applied                  winner  win_by_runs  win_by_wickets player_of_match                                      venue         umpire1   umpire2 umpire3
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad  Royal Challengers Bangalore  Royal Challengers Bangalore         field  normal           0     Sunrisers Hyderabad           35               0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar  NJ Llong     NaN
# 1   2    2017       Pune  2017-04-06       Mumbai Indians       Rising Pune Supergiant       Rising Pune Supergiant         field  normal           0  Rising Pune Supergiant            0               7       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore    S Ravi     NaN

# %%
#matches $ innings
#matches: include playing 11
#innings: when he gets a chance to bat or bowl

#batting average: runs/dismissals
#batting SR: (runs/balls)*100
#runs per innings: runs/innings
#balls per boundary: balls/(fours + sixes)
#dot% = total_dots/balls
#boundary% = total_boundaries/balls
#non-boundary = (0s + 1s + 2s + 3s)/balls

# %%
batsman = 'Surya kumar yadav'
matches = 5
innings = 5
#0(2), 52(19) 4s = 5 6s = 4, 0(2), 78(53) 4s = 7 6s = 3, 10(8) 4s = 2
runs_scored = [0, 52, 0, 78, 10]
runs = 140
balls = 84
fours = 14
sixes = 7
dismissals = 5

# %%
batting_average = runs/dismissals

# %%
batting_average
# Out:
# 28.0

# %%
batting_SR = (runs/balls)*100

# %%
batting_SR
# Out:
# 166.66666666666669

# %%
RPI = runs/innings

# %%
BPB = balls/(fours + sixes)

# %%
print("Surya kumar yadav in IPL 2024")
print("runs", runs)
print("Avg:", batting_average)
print("SR:", batting_SR)
print("RPI", RPI)
print("BPB", BPB)
# Out:
# Surya kumar yadav in IPL 2024
# runs 140
# Avg: 28.0
# SR: 166.66666666666669
# RPI 28.0
# BPB 4.0

# %%
df = pd.read_csv('deliveries.csv')

# %%
df.head(2)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  ball    batsman non_striker    bowler  is_super_over  wide_runs  bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs player_dismissed dismissal_kind fielder
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     1  DA Warner    S Dhawan  TS Mills              0          0         0            0            0             0             0           0           0              NaN            NaN     NaN
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     2  DA Warner    S Dhawan  TS Mills              0          0         0            0            0             0             0           0           0              NaN            NaN     NaN

# %%
f1 = lambda x: x*x

# %%
f1(3)
# Out:
# 9

# %%
df['isDot'] = df['batsman_runs'].apply(lambda x : 1 if x == 0 else 0)
df['isOne'] = df['batsman_runs'].apply(lambda x : 1 if x == 1 else 0)
df['isTwo'] = df['batsman_runs'].apply(lambda x : 1 if x == 2 else 0)
df['isThree'] = df['batsman_runs'].apply(lambda x : 1 if x == 3 else 0)

df['isFour'] = df['batsman_runs'].apply(lambda x : 1 if x == 4 else 0)
df['isSix'] = df['batsman_runs'].apply(lambda x : 1 if x == 6 else 0)

# %%
df.head(5)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  ball    batsman non_striker    bowler  is_super_over  wide_runs  bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs player_dismissed dismissal_kind fielder  isDot  isOne  isTwo  isThree  isFour  isSix
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     1  DA Warner    S Dhawan  TS Mills              0          0         0            0            0             0             0           0           0              NaN            NaN     NaN      1      0      0        0       0      0
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     2  DA Warner    S Dhawan  TS Mills              0          0         0            0            0             0             0           0           0              NaN            NaN     NaN      1      0      0        0       0      0
# ...

# %%
df['batsman'].head(10)
# Out:
# 0    DA Warner
# 1    DA Warner
# 2    DA Warner
# 3    DA Warner
# 4    DA Warner
# 5     S Dhawan
# 6     S Dhawan
# 7     S Dhawan
# 8    DA Warner
# 9    DA Warner
# Name: batsman, dtype: object

# %%
df['batsman'].unique()
# Out:
# array(['DA Warner', 'S Dhawan', 'MC Henriques', 'Yuvraj Singh',
#        'DJ Hooda', 'BCJ Cutting', 'CH Gayle', 'Mandeep Singh', 'TM Head',
#        'KM Jadhav', 'SR Watson', 'Sachin Baby', 'STR Binny', 'S Aravind',
#        'YS Chahal', 'TS Mills', 'A Choudhary', 'PA Patel', 'JC Buttler',
#        'RG Sharma', 'N Rana', 'AT Rayudu', 'KH Pandya', 'KA Pollard',
#        'HH Pandya', 'TG Southee', 'AM Rahane', 'MA Agarwal', 'SPD Smith',
#        'BA Stokes', 'MS Dhoni', 'JJ Roy', 'BB McCullum', 'SK Raina',
#        'AJ Finch', 'KD Karthik', 'G Gambhir', 'CA Lynn', 'MK Tiwary',
#        'DT Christian', 'HM Amla', 'M Vohra', 'WP Saha', 'AR Patel',
#        'GJ Maxwell', 'DA Miller', 'Vishnu Vinod', 'Iqbal Abdulla',
#        'P Negi', 'AP Tare', 'SW Billings', 'KK Nair', 'SV Samson',
#        'RR Pant', 'CH Morris', 'CR Brathwaite', 'PJ Cummins', 'A Mishra',
#        'S Nadeem', 'Z Khan', 'DR Smith', 'DS Kulkarni', 'P Kumar',
# ...

# %%
len(df['batsman'].unique())
# Out:
# 516

# %%
#groupby function
#when we need to sum of runs of the particular batsman scored 
# Group by 'batsman' and 'inning' and calculate the sum of 'batsman_runs'

# %%
df.groupby(['batsman' , 'inning'])['batsman_runs'].sum()
# Out:
# batsman               inning
# A Ashish Reddy        1          166
#                       2          114
# A Chandila            1            4
# A Chopra              1           51
#                       2            2
# A Choudhary           1           15
#                       2           10
# A Dananjaya           1            4
# A Flintoff            1           22
#                       2           40
# A Hales               1           53
#                       2           99
# A Joseph              2           15
# A Kumble              1           11
#                       2           24
# A Mishra              1          145
#                       2          223
# A Mithun              1            8
#                       2           26
# A Mukund              1           19
#                       2            0
# A Nehra               1            6
#                       2           35
# A Singh               1            1
# ...

# %%
df.groupby(['batsman' , 'match_id'])['batsman_runs'].sum()
# Out:
# batsman               match_id
# A Ashish Reddy        346          10
#                       352           3
#                       359           8
#                       373          10
#                       376           4
#                       384           7
#                       388          14
#                       394          16
#                       397           4
#                       402          19
#                       405           7
#                       414          36
#                       416          14
#                       428           5
#                       432           3
#                       529          13
#                       531          15
#                       544          22
#                       551           6
#                       572          17
#                       580          32
#                       584          13
#                       603           2
# A Chandila            373           0
# ...

# %%
df.groupby(['batsman' , 'match_id'])['batsman_runs'].sum().head(10)
# Out:
# batsman         match_id
# A Ashish Reddy  346         10
#                 352          3
#                 359          8
#                 373         10
#                 376          4
#                 384          7
#                 388         14
#                 394         16
#                 397          4
#                 402         19
# Name: batsman_runs, dtype: int64

# %%
df[df.batsman == 'DA Warner'].groupby(['batsman' , 'match_id'])['batsman_runs'].sum()
# Out:
# batsman    match_id
# DA Warner  1            14
#            6            76
#            10           49
#            14           26
#            19           70
#            21            4
#            25           43
#            32           51
#            36          126
#            39           30
#            43           40
#            47            6
#            52           69
#            57           37
#            141          51
#            146          36
#            150          21
#            154          36
#            158           4
#            170          15
#            172           0
#            185           6
#            189          57
#            197          33
#            200         107
#            203           4
#            209          33
#            213           0
#            218           6
#            221          31
#            224           0
#            229           5
#            238           1
# ...

# %%
#what are the scores different batsman in each match
df.groupby(['match_id' , 'batsman'])['batsman_runs'].sum()
# Out:
# match_id  batsman
# 1         A Choudhary               6
#           BCJ Cutting              16
#           CH Gayle                 32
#           DA Warner                14
#           DJ Hooda                 16
#           KM Jadhav                31
#           MC Henriques             52
#           Mandeep Singh            24
#           S Aravind                 0
#           S Dhawan                 40
#           SR Watson                22
#           STR Binny                11
#           Sachin Baby               1
#           TM Head                  30
#           TS Mills                  6
#           YS Chahal                 3
#           Yuvraj Singh             62
# 2         AM Rahane                60
#           AT Rayudu                10
#           BA Stokes                21
#           HH Pandya                35
#           JC Buttler               38
#           KA Pollard               27
#           KH Pandya                 3
# ...

# %%
df.groupby(['batsman'])['batsman_runs'].sum()
# Out:
# batsman
# A Ashish Reddy           280
# A Chandila                 4
# A Chopra                  53
# A Choudhary               25
# A Dananjaya                4
# A Flintoff                62
# A Hales                  152
# A Joseph                  15
# A Kumble                  35
# A Mishra                 368
# A Mithun                  34
# A Mukund                  19
# A Nehra                   41
# A Singh                    2
# A Symonds                974
# A Turner                   4
# A Uniyal                   4
# A Zampa                    5
# AA Bilakhia               69
# AA Chavan                 12
# AA Jhunjhunwala          217
# AA Noffke                  9
# AB Agarkar               179
# AB Barath                 42
# AB Dinda                  26
# AB McDonald              123
# AB de Villiers          4428
# AC Blizzard              120
# AC Gilchrist            2069
# AC Thomas                 20
# AC Voges                 181
# ...

# %%
pd.DataFrame(df.groupby(['batsman'])['batsman_runs'].sum())
# Out:
#                       batsman_runs
# batsman
# A Ashish Reddy                 280
# A Chandila                       4
# A Chopra                        53
# A Choudhary                     25
# A Dananjaya                      4
# A Flintoff                      62
# A Hales                        152
# A Joseph                        15
# A Kumble                        35
# A Mishra                       368
# A Mithun                        34
# A Mukund                        19
# A Nehra                         41
# A Singh                          2
# A Symonds                      974
# A Turner                         4
# A Uniyal                         4
# A Zampa                          5
# AA Bilakhia                     69
# AA Chavan                       12
# AA Jhunjhunwala                217
# AA Noffke                        9
# AB Agarkar                     179
# AB Barath                       42
# AB Dinda                        26
# ...

# %%
pd.DataFrame(df.groupby(['batsman'])['batsman_runs'].sum()).sort_values(by = 'batsman_runs')
# Out:
#                       batsman_runs
# batsman
# Abdur Razzak                     0
# K Ahmed                          0
# RR Bhatkal                       0
# C Nanda                          0
# J Denly                          0
# IC Pandey                        0
# Sunny Gupta                      0
# YA Abdulla                       0
# V Pratap Singh                   0
# L Ablish                         0
# S Kaushik                        0
# S Ladda                          0
# S Lamichhane                     0
# P Raj                            0
# U Kaul                           0
# ND Doshi                         0
# P Parameswaran                   1
# M de Lange                       1
# P Krishna                        1
# SE Bond                          1
# Shoaib Ahmed                     1
# LH Ferguson                      1
# BE Hendricks                     1
# DJ Muthuswami                    1
# NJ Rimmington                    1
# ...

# %%
pd.DataFrame(df.groupby(['batsman'])['batsman_runs'].sum()).sort_values(by = 'batsman_runs' , ascending = False)
# Out:
#                       batsman_runs
# batsman
# V Kohli                       5434
# SK Raina                      5415
# RG Sharma                     4914
# DA Warner                     4741
# S Dhawan                      4632
# CH Gayle                      4560
# MS Dhoni                      4477
# RV Uthappa                    4446
# AB de Villiers                4428
# G Gambhir                     4223
# AM Rahane                     3850
# KD Karthik                    3688
# SR Watson                     3614
# AT Rayudu                     3326
# YK Pathan                     3241
# BB McCullum                   2893
# PA Patel                      2874
# MK Pandey                     2872
# KA Pollard                    2784
# Yuvraj Singh                  2765
# V Sehwag                      2728
# M Vijay                       2590
# SE Marsh                      2489
# JH Kallis                     2427
# DR Smith                      2385
# ...

# %%
pd.DataFrame(df.groupby(['batsman'])['batsman_runs'].sum()).sort_values(by = 'batsman_runs' , ascending = False).head(10)
# Out:
#                 batsman_runs
# batsman
# V Kohli                 5434
# SK Raina                5415
# RG Sharma               4914
# DA Warner               4741
# S Dhawan                4632
# CH Gayle                4560
# MS Dhoni                4477
# RV Uthappa              4446
# AB de Villiers          4428
# G Gambhir               4223

# %%
df[df['batting_team'] == 'Sunrisers Hyderabad'].head(100)
# Out:
#     match_id  inning         batting_team                 bowling_team  over  ball       batsman   non_striker       bowler  is_super_over  wide_runs  bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs player_dismissed dismissal_kind        fielder  isDot  isOne  isTwo  isThree  isFour  isSix
# 0          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     1     DA Warner      S Dhawan     TS Mills              0          0         0            0            0             0             0           0           0              NaN            NaN            NaN      1      0      0        0       0      0
# 1          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     2     DA Warner      S Dhawan     TS Mills              0          0         0            0            0             0             0           0           0              NaN            NaN            NaN      1      0      0        0       0      0
# ...

# %%
df = pd.read_csv('deliveries.csv')

# %%
df.groupby(['batsman'])['batsman_runs'].sum().head(2)
# Out:
# batsman
# A Ashish Reddy    280
# A Chandila          4
# Name: batsman_runs, dtype: int64

# %%
pd.DataFrame(df.groupby(['batsman'])['batsman_runs'].sum().head(2))
# Out:
#                 batsman_runs
# batsman
# A Ashish Reddy           280
# A Chandila                 4

# %%
pd.DataFrame(df.groupby(['batsman'])['batsman_runs'].sum()).reset_index().head(5)
# Out:
#           batsman  batsman_runs
# 0  A Ashish Reddy           280
# 1      A Chandila             4
# 2        A Chopra            53
# 3     A Choudhary            25
# 4     A Dananjaya             4

# %%
df.index
# Out:
# RangeIndex(start=0, stop=179078, step=1)

# %%
#rename the column, row name

# %%
pd.DataFrame(df.groupby(['batsman'])['batsman_runs'].sum()).reset_index().rename(columns = {'batsman_runs' : 'runs'}).head(5)
# Out:
#           batsman  runs
# 0  A Ashish Reddy   280
# 1      A Chandila     4
# 2        A Chopra    53
# 3     A Choudhary    25
# 4     A Dananjaya     4

# %%
#alternate to put head()

# %%
runs = pd.DataFrame(df.groupby(['batsman'])['batsman_runs'].sum()).reset_index().rename(columns = {'batsman_runs' : 'runs'})

# %%
runs.head(2)
# Out:
#           batsman  runs
# 0  A Ashish Reddy   280
# 1      A Chandila     4

# %%
#count the no. of balls faced by the batsman with the help of match id

# %%
balls = pd.DataFrame(df.groupby(['batsman'])['match_id'].sum()).reset_index().rename(columns = {'match_id' : 'balls'})

# %%
balls.head(3)
# Out:
#           batsman  balls
# 0  A Ashish Reddy  90024
# 1      A Chandila   2815
# 2        A Chopra   7602

# %%
#displaying the no. of matches played

# %%
df.groupby(['batsman'])['match_id']

# %%
df.groupby(['batsman'])['match_id'].apply(lambda x : len(list(np.unique(x))))
# Out:
# batsman
# A Ashish Reddy           23
# A Chandila                2
# A Chopra                  6
# A Choudhary               3
# A Dananjaya               1
# A Flintoff                3
# A Hales                   6
# A Joseph                  1
# A Kumble                 15
# A Mishra                 54
# A Mithun                  6
# A Mukund                  2
# A Nehra                  17
# A Singh                   5
# A Symonds                36
# A Turner                  4
# A Uniyal                  2
# A Zampa                   2
# AA Bilakhia               7
# AA Chavan                 3
# AA Jhunjhunwala          15
# AA Noffke                 1
# AB Agarkar               18
# AB Barath                 3
# AB Dinda                 16
# AB McDonald               9
# AB de Villiers          142
# AC Blizzard               7
# AC Gilchrist             80
# AC Thomas                 4
# AC Voges                  7
# AD Mascarenhas           11
# AD Mathews               41
# ...

# %%
pd.DataFrame(df.groupby(['batsman'])['match_id'].apply(lambda x : len(list(np.unique(x)))))
# Out:
#                       match_id
# batsman
# A Ashish Reddy              23
# A Chandila                   2
# A Chopra                     6
# A Choudhary                  3
# A Dananjaya                  1
# A Flintoff                   3
# A Hales                      6
# A Joseph                     1
# A Kumble                    15
# A Mishra                    54
# A Mithun                     6
# A Mukund                     2
# A Nehra                     17
# A Singh                      5
# A Symonds                   36
# A Turner                     4
# A Uniyal                     2
# A Zampa                      2
# AA Bilakhia                  7
# AA Chavan                    3
# AA Jhunjhunwala             15
# AA Noffke                    1
# AB Agarkar                  18
# AB Barath                    3
# AB Dinda                    16
# AB McDonald                  9
# AB de Villiers             142
# AC Blizzard                  7
# AC Gilchrist                80
# ...

# %%
pd.DataFrame(df.groupby(['batsman'])['match_id'].apply(lambda x : len(list(np.unique(x))))).reset_index()
# Out:
#                   batsman  match_id
# 0          A Ashish Reddy        23
# 1              A Chandila         2
# 2                A Chopra         6
# 3             A Choudhary         3
# 4             A Dananjaya         1
# 5              A Flintoff         3
# 6                 A Hales         6
# 7                A Joseph         1
# 8                A Kumble        15
# 9                A Mishra        54
# 10               A Mithun         6
# 11               A Mukund         2
# 12                A Nehra        17
# 13                A Singh         5
# 14              A Symonds        36
# 15               A Turner         4
# 16               A Uniyal         2
# 17                A Zampa         2
# 18            AA Bilakhia         7
# 19              AA Chavan         3
# 20        AA Jhunjhunwala        15
# 21              AA Noffke         1
# 22             AB Agarkar        18
# 23              AB Barath         3
# 24               AB Dinda        16
# ...

# %%
innings = pd.DataFrame(df.groupby(['batsman'])['match_id'].apply(lambda x : len(list(np.unique(x))))).reset_index().rename(columns = {'match_id' : 'innings'})

# %%
innings.head(2)
# Out:
#           batsman  innings
# 0  A Ashish Reddy       23
# 1      A Chandila        2

# %%
df.head(2)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  ball    batsman non_striker    bowler  is_super_over  wide_runs  bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs player_dismissed dismissal_kind fielder  isDot  isOne  isTwo  isThree  isFour  isSix
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     1  DA Warner    S Dhawan  TS Mills              0          0         0            0            0             0             0           0           0              NaN            NaN     NaN      1      0      0        0       0      0
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     2  DA Warner    S Dhawan  TS Mills              0          0         0            0            0             0             0           0           0              NaN            NaN     NaN      1      0      0        0       0      0

# %%
#player no. of dismisssals

# %%
df.groupby(['batsman'])['player_dismissed'].count()
# Out:
# batsman
# A Ashish Reddy           15
# A Chandila                1
# A Chopra                  5
# A Choudhary               2
# A Dananjaya               0
# A Flintoff                2
# A Hales                   6
# A Joseph                  0
# A Kumble                  2
# A Mishra                 30
# A Mithun                  5
# A Mukund                  2
# A Nehra                   8
# A Singh                   4
# A Symonds                26
# A Turner                  3
# A Uniyal                  1
# A Zampa                   2
# AA Bilakhia               5
# AA Chavan                 1
# AA Jhunjhunwala          14
# AA Noffke                 1
# AB Agarkar                8
# AB Barath                 2
# AB Dinda                  9
# AB McDonald               5
# AB de Villiers          104
# AC Blizzard               7
# AC Gilchrist             76
# AC Thomas                 2
# AC Voges                  6
# AD Mascarenhas           10
# AD Mathews               31
# ...

# %%
dismissals = pd.DataFrame(df.groupby(['batsman'])['player_dismissed'].count()).reset_index().rename(columns = {'player_dismissed' : 'dismissals'})
sixes = pd.DataFrame(df.groupby(['batsman'])['isSix'].sum()).reset_index().rename(columns = {'isSix' : 'sixes'})

# %%
dismissals.head(10)
# Out:
#           batsman  dismissals
# 0  A Ashish Reddy          15
# 1      A Chandila           1
# 2        A Chopra           5
# 3     A Choudhary           2
# 4     A Dananjaya           0
# 5      A Flintoff           2
# 6         A Hales           6
# 7        A Joseph           0
# 8        A Kumble           2
# 9        A Mishra          30

# %%
sixes.head(2)
# Out:
#           batsman  sixes
# 0  A Ashish Reddy     15
# 1      A Chandila      0

# %%
df.groupby(['batsman'])['isSix'].count()
# Out:
# batsman
# A Ashish Reddy           196
# A Chandila                 7
# A Chopra                  75
# A Choudhary               20
# A Dananjaya                5
# A Flintoff                57
# A Hales                  119
# A Joseph                  13
# A Kumble                  49
# A Mishra                 410
# A Mithun                  26
# A Mukund                  23
# A Nehra                   63
# A Singh                   10
# A Symonds                781
# A Turner                  11
# A Uniyal                   7
# A Zampa                    8
# AA Bilakhia               88
# AA Chavan                 11
# AA Jhunjhunwala          218
# AA Noffke                 12
# AB Agarkar               160
# AB Barath                 43
# AB Dinda                  50
# AB McDonald              103
# AB de Villiers          2977
# AC Blizzard               91
# AC Gilchrist            1555
# AC Thomas                 19
# AC Voges                 143
# ...

# %%
six = pd.DataFrame(df.groupby(['batsman'])['isSix'].sum()).reset_index().rename(columns = {'isSix' : 'six'})

# %%
six.head(10)
# Out:
#           batsman  six
# 0  A Ashish Reddy   15
# 1      A Chandila    0
# 2        A Chopra    0
# 3     A Choudhary    1
# 4     A Dananjaya    0
# 5      A Flintoff    2
# 6         A Hales    6
# 7        A Joseph    0
# 8        A Kumble    0
# 9        A Mishra    5

# %%
four = pd.DataFrame(df.groupby(['batsman'])['isFour'].sum()).reset_index().rename(columns = {'isFour' : 'four'})

# %%
four.head(5)
# Out:
#           batsman  four
# 0  A Ashish Reddy    16
# 1      A Chandila     0
# 2        A Chopra     7
# 3     A Choudhary     1
# 4     A Dananjaya     0

# %%
df.head(50)
# Out:
#     match_id  inning         batting_team                 bowling_team  over  ball       batsman   non_striker       bowler  is_super_over  wide_runs  bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs player_dismissed dismissal_kind        fielder  isDot  isOne  isTwo  isThree  isFour  isSix
# 0          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     1     DA Warner      S Dhawan     TS Mills              0          0         0            0            0             0             0           0           0              NaN            NaN            NaN      1      0      0        0       0      0
# 1          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     2     DA Warner      S Dhawan     TS Mills              0          0         0            0            0             0             0           0           0              NaN            NaN            NaN      1      0      0        0       0      0
# ...

# %%
four = pd.DataFrame(df.groupby(['batsman'])['isFour'].sum()).reset_index().rename(columns={'isFour': 'four'})

# %%
four.head(10)
# Out:
#           batsman  four
# 0  A Ashish Reddy    16
# 1      A Chandila     0
# 2        A Chopra     7
# 3     A Choudhary     1
# 4     A Dananjaya     0
# 5      A Flintoff     5
# 6         A Hales    13
# 7        A Joseph     2
# 8        A Kumble     3
# 9        A Mishra    30

# %%
runs = pd.DataFrame(df.groupby(['batsman'])['batsman_runs'].sum()).reset_index().rename(columns = {'batsman_runs' : 'runs'})
balls = pd.DataFrame(df.groupby(['batsman'])['match_id'].count()).reset_index().rename(columns = {'match_id' : 'balls'})
innings = pd.DataFrame(df.groupby(['batsman'])['match_id'].apply(lambda x : len(list(np.unique(x))))).reset_index().rename(columns = {'match_id' : 'innings'})
dismissals = pd.DataFrame(df.groupby(['batsman'])['player_dismissed'].count()).reset_index().rename(columns = {'player_dismissed' : 'dismissals'})
six = pd.DataFrame(df.groupby(['batsman'])['isSix'].sum()).reset_index().rename(columns={'isFour': 'six'})
fours = pd.DataFrame(df.groupby(['batsman'])['isFour'].sum()).reset_index().rename(columns={'isFour': 'fours'})

# %%
pd.merge(innings, runs, on = 'batsman').merge(balls, on = 'batsman').merge(dismissals, on = 'batsman').merge(six, on = 'batsman').merge(fours, on = 'batsman').head(4)
# Out:
#           batsman  innings  runs  balls  dismissals  isSix  fours
# 0  A Ashish Reddy       23   280    196          15     15     16
# 1      A Chandila        2     4      7           1      0      0
# 2        A Chopra        6    53     75           5      0      7
# 3     A Choudhary        3    25     20           2      1      1

# %%
pd.merge(innings, runs, on = 'batsman').merge(balls, on = 'batsman').merge(dismissals, on = 'batsman').merge(six, on = 'batsman').merge(fours, on = 'batsman')
# Out:
#                   batsman  innings  runs  balls  dismissals  isSix  fours
# 0          A Ashish Reddy       23   280    196          15     15     16
# 1              A Chandila        2     4      7           1      0      0
# 2                A Chopra        6    53     75           5      0      7
# 3             A Choudhary        3    25     20           2      1      1
# 4             A Dananjaya        1     4      5           0      0      0
# 5              A Flintoff        3    62     57           2      2      5
# 6                 A Hales        6   152    119           6      6     13
# 7                A Joseph        1    15     13           0      0      2
# 8                A Kumble       15    35     49           2      0      3
# 9                A Mishra       54   368    410          30      5     30
# 10               A Mithun        6    34     26           5      1      4
# 11               A Mukund        2    19     23           2      0      1
# ...

# %%
mega = pd.merge(innings, runs, on = 'batsman').merge(balls, on = 'batsman').merge(dismissals, on = 'batsman').merge(six, on = 'batsman').merge(fours, on = 'batsman')

# %%
mega.head(2)
# Out:
#           batsman  innings  runs  balls  dismissals  isSix  fours
# 0  A Ashish Reddy       23   280    196          15     15     16
# 1      A Chandila        2     4      7           1      0      0

# %%
#player runs in 1st $ 2nd innings - plot

# %%
df.head(4)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  ball    batsman non_striker    bowler  is_super_over  wide_runs  bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs player_dismissed dismissal_kind fielder  isDot  isOne  isTwo  isThree  isFour  isSix
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     1  DA Warner    S Dhawan  TS Mills              0          0         0            0            0             0             0           0           0              NaN            NaN     NaN      1      0      0        0       0      0
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     2  DA Warner    S Dhawan  TS Mills              0          0         0            0            0             0             0           0           0              NaN            NaN     NaN      1      0      0        0       0      0
# ...

# %%
mega['RPI'] = mega.apply(lambda x: x['runs'] / x['innings'], axis=1)

# %%
mega.head(2)
# Out:
#           batsman  innings  runs  balls  dismissals  isSix  fours        RPI
# 0  A Ashish Reddy       23   280    196          15     15     16  12.173913
# 1      A Chandila        2     4      7           1      0      0   2.000000

# %%
df.head(1)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  ball    batsman non_striker    bowler  is_super_over  wide_runs  bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs player_dismissed dismissal_kind fielder  isDot  isOne  isTwo  isThree  isFour  isSix
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     1  DA Warner    S Dhawan  TS Mills              0          0         0            0            0             0             0           0           0              NaN            NaN     NaN      1      0      0        0       0      0

# %%
df[df.inning == 1].reset_index(drop = True).head(200)
# Out:
#      match_id  inning         batting_team                 bowling_team  over  ball       batsman   non_striker       bowler  is_super_over  wide_runs  bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs player_dismissed     dismissal_kind        fielder  isDot  isOne  isTwo  isThree  isFour  isSix
# 0           1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     1     DA Warner      S Dhawan     TS Mills              0          0         0            0            0             0             0           0           0              NaN                NaN            NaN      1      0      0        0       0      0
# ...

# %%
def Byinnings(df, current_innings):

    df = df[df.inning == current_innings]
    df.reset_index(inplace = True, drop = True)
    
    df['isDot'] = df['batsman_runs'].apply(lambda x : 1 if x == 0 else 0)
    df['isOne'] = df['batsman_runs'].apply(lambda x : 1 if x == 1 else 0)
    df['isTwo'] = df['batsman_runs'].apply(lambda x : 1 if x == 2 else 0)
    df['isThree'] = df['batsman_runs'].apply(lambda x : 1 if x == 3 else 0)

    df['isFour'] = df['batsman_runs'].apply(lambda x : 1 if x == 4 else 0)
    df['isSix'] = df['batsman_runs'].apply(lambda x : 1 if x == 6 else 0)
    
    runs = pd.DataFrame(df.groupby(['batsman'])['batsman_runs'].sum()).reset_index().rename(columns = {'batsman_runs' : 'runs'})
    balls = pd.DataFrame(df.groupby(['batsman'])['match_id'].count()).reset_index().rename(columns = {'match_id' : 'balls'})
    innings = pd.DataFrame(df.groupby(['batsman'])['match_id'].apply(lambda x : len(list(np.unique(x))))).reset_index().rename(columns = {'match_id' : 'innings'})
    dismissals = pd.DataFrame(df.groupby(['batsman'])['player_dismissed'].count()).reset_index().rename(columns = {'player_dismissed' : 'dismissals'})    
    six = pd.DataFrame(df.groupby(['batsman'])['isSix'].sum()).reset_index().rename(columns={'isFour': 'six'})
    fours = pd.DataFrame(df.groupby(['batsman'])['isFour'].sum()).reset_index().rename(columns={'isFour': 'fours'})

    df = pd.merge(innings, runs, on = 'batsman').merge(balls, on = 'batsman').merge(dismissals, on = 'batsman').merge(six, on = 'batsman').merge(fours, on = 'batsman')
    df['RPI'] = mega.apply(lambda x: x['runs'] / x['innings'], axis=1)

    return df

# %%
ing1_df = Byinnings(df, 1)

# %%
ing2_df = Byinnings(df, 2)

# %%
ing1_df.head(20)
# Out:
#             batsman  innings  runs  balls  dismissals  isSix  fours        RPI
# 0    A Ashish Reddy       13   166    115           7     10      6  12.173913
# 1        A Chandila        2     4      7           1      0      0   2.000000
# 2          A Chopra        5    51     72           4      0      7   8.833333
# 3       A Choudhary        1    15     12           0      0      1   8.333333
# 4       A Dananjaya        1     4      5           0      0      0   4.000000
# 5        A Flintoff        1    22     14           0      1      2  20.666667
# 6           A Hales        3    53     53           3      0      5  25.333333
# 7          A Kumble        5    11     16           1      0      1  15.000000
# 8          A Mishra       25   145    176          15      1     13   2.333333
# 9          A Mithun        2     8      5           1      0      1   6.814815
# 10         A Mukund        1    19     22           1      0      1   5.666667
# ...

# %%
ing2_df.head(20)
# Out:
#             batsman  innings  runs  balls  dismissals  isSix  fours        RPI
# 0    A Ashish Reddy       10   114     81           8      5     10  12.173913
# 1          A Chopra        1     2      3           1      0      0   2.000000
# 2       A Choudhary        2    10      8           2      1      0   8.833333
# 3        A Flintoff        2    40     43           2      1      3   8.333333
# 4           A Hales        3    99     66           3      6      8   4.000000
# 5          A Joseph        1    15     13           0      0      2  20.666667
# 6          A Kumble       10    24     33           1      0      2  25.333333
# 7          A Mishra       29   223    234          15      4     17  15.000000
# 8          A Mithun        4    26     21           4      1      3   2.333333
# 9          A Mukund        1     0      1           1      0      0   6.814815
# 10          A Nehra        8    35     44           3      1      3   5.666667
# ...

# %%
ing1_df[['batsman','RPI']].rename(columns ={'RPI' : 'Ing1_RPI'})
# Out:
#                   batsman   Ing1_RPI
# 0          A Ashish Reddy  12.173913
# 1              A Chandila   2.000000
# 2                A Chopra   8.833333
# 3             A Choudhary   8.333333
# 4             A Dananjaya   4.000000
# 5              A Flintoff  20.666667
# 6                 A Hales  25.333333
# 7                A Kumble  15.000000
# 8                A Mishra   2.333333
# 9                A Mithun   6.814815
# 10               A Mukund   5.666667
# 11                A Nehra   9.500000
# 12                A Singh   2.411765
# 13              A Symonds   0.400000
# 14               A Turner  27.055556
# 15               A Uniyal   1.000000
# 16            AA Bilakhia   2.000000
# 17              AA Chavan   2.500000
# 18        AA Jhunjhunwala   9.857143
# 19             AB Agarkar   4.000000
# 20               AB Dinda  14.466667
# 21            AB McDonald   9.000000
# 22         AB de Villiers   9.944444
# 23            AC Blizzard  14.000000
# ...

# %%
ing2_df[['batsman','RPI']].rename(columns ={'RPI' : 'Ing2_RPI'})
# Out:
#                batsman   Ing2_RPI
# 0       A Ashish Reddy  12.173913
# 1             A Chopra   2.000000
# 2          A Choudhary   8.833333
# 3           A Flintoff   8.333333
# 4              A Hales   4.000000
# 5             A Joseph  20.666667
# 6             A Kumble  25.333333
# 7             A Mishra  15.000000
# 8             A Mithun   2.333333
# 9             A Mukund   6.814815
# 10             A Nehra   5.666667
# 11             A Singh   9.500000
# 12           A Symonds   2.411765
# 13            A Turner   0.400000
# 14            A Uniyal  27.055556
# 15             A Zampa   1.000000
# 16         AA Bilakhia   2.000000
# 17           AA Chavan   2.500000
# 18     AA Jhunjhunwala   9.857143
# 19           AA Noffke   4.000000
# 20          AB Agarkar  14.466667
# 21           AB Barath   9.000000
# 22            AB Dinda   9.944444
# 23         AB McDonald  14.000000
# 24      AB de Villiers   1.625000
# 25         AC Blizzard  13.666667
# ...
